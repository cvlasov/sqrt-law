# %%
import matplotlib.pyplot as plt

# %%
x_fake = [7.68, 83.6652, 162.5088, 240.8448, 314.5728, 398.1312, 479.3088, 554.88, 635.9808, 707.7888]
y1_fake = [0.625,0.65,0.675,0.7,0.725,0.75,0.775,0.8,0.825,0.85]
y2_fake = [0.575,0.6,0.625,0.65,0.675,0.7,0.725,0.75,0.775,0.8]
y3_fake = [0.525,0.55,0.575,0.6,0.625,0.65,0.675,0.7,0.725,0.75]

# %%
plt.figure(figsize=(12,10))

plt.subplot(2,2,1)
plt.plot(x_fake, y1_fake, 'r+:', label='constant 1')
plt.plot(x_fake, y2_fake, 'bs:', label='constant 2')
plt.plot(x_fake, y3_fake, 'go:', label='constant 3')
plt.axis([0,800,0.5,1.0])
plt.xlabel(r'Cover size N in pixels ($\times 10^4$)')
plt.ylabel(r'$1-P_E$')
plt.title(r'$O(1)$')
plt.legend()

plt.subplot(2,2,2)
plt.plot(x_fake, y1_fake, 'r+:', label='constant 1')
plt.plot(x_fake, y2_fake, 'bs:', label='constant 2')
plt.plot(x_fake, y3_fake, 'go:', label='constant 3')
plt.axis([0,800,0.5,1.0])
plt.xlabel(r'Cover size N in pixels ($\times 10^4$)')
plt.ylabel(r'$1-P_E$')
plt.title(r'$O(\sqrt{N})$')
plt.legend()

plt.subplot(2,2,3)
plt.plot(x_fake, y1_fake, 'r+:', label='constant 1')
plt.plot(x_fake, y2_fake, 'bs:', label='constant 2')
plt.plot(x_fake, y3_fake, 'go:', label='constant 3')
plt.axis([0,800,0.5,1.0])
plt.xlabel(r'Cover size N in pixels ($\times 10^4$)')
plt.ylabel(r'$1-P_E$')
plt.title(r'$O(\sqrt{N}\log{N})$')
plt.legend()

plt.subplot(2,2,4)
plt.plot(x_fake, y1_fake, 'r+:', label='constant 1')
plt.plot(x_fake, y2_fake, 'bs:', label='constant 2')
plt.plot(x_fake, y3_fake, 'go:', label='constant 3')
plt.axis([0,800,0.5,1.0])
plt.xlabel(r'Cover size N in pixels ($\times 10^4$)')
plt.ylabel(r'$1-P_E$')
plt.title(r'$O(N)$')
plt.legend()

plt.tight_layout()
plt.savefig('graph_template.png')
plt.show()
